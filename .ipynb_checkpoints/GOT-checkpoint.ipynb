# %%
import pandas as pd
import numpy as np
import networkx as nx
import math
import requests
import urllib.request
from bs4 import BeautifulSoup
import bleach
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from fa2 import ForceAtlas2
import pickle

# %% [markdown]
# ## Data Extraction

# %% [markdown]
# There are two tables listing main characters in wikipedia page. We will conduct network analysis on these charactors.
#
# Source : https://en.wikipedia.org/wiki/List_of_Game_of_Thrones_characters.

# %%
table1=pd.read_csv("table-1.csv")
table2=pd.read_csv("table-2.csv")

# %%
list1=table1.Character.tolist()[1:]
list2=table2.Character.tolist()[1:]
list_full=list1 + list2
list_full
# Out:
# ['Eddard Stark',
#  'Robert Baratheon',
#  'Jaime Lannister',
#  'Catelyn Stark',
#  'Cersei Lannister',
#  'Daenerys Targaryen',
#  'Jorah Mormont',
#  'Viserys Targaryen',
#  'Jon Snow',
#  'Sansa Stark',
#  'Arya Stark',
#  'Robb Stark',
#  'Theon Greyjoy',
#  'Bran Stark',
#  'Joffrey Baratheon',
#  'Sandor Clegane',
#  'Tyrion Lannister',
#  'Khal Drogo',
#  'Petyr Baelish',
#  'Davos Seaworth',
#  'Samwell Tarly',
#  'Stannis Baratheon',
#  'Melisandre',
#  'Jeor Mormont',
#  'Bronn',
#  'Varys',
#  'Shae',
#  'Margaery Tyrell',
#  'Tywin Lannister',
#  'Talisa Maegyr',
#  'Ygritte',
#  'Gendry',
#  'Tormund Giantsbane',
#  'Brienne of Tarth',
#  'Ramsay Bolton',
#  'Gilly',
#  'Daario Naharis',
#  'Missandei',
#  'Ellaria Sand',
#  'Tommen Baratheon',
#  "Jaqen H'ghar",
#  'Roose Bolton',
#  'The High Sparrow',
#  'Grey Worm',
#  'Grand Maester Pycelle',
#  'Meryn Trant',
#  'Hodor',
#  'Grenn',
#  'Osha',
#  'Rickon Stark',
#  'Ros',
#  'Gregor Clegane',
#  'Janos Slynt',
#  'Lancel Lannister',
#  'Myrcella Baratheon',
#  'Rodrik Cassel',
#  'Maester Luwin',
#  'Irri',
#  'Doreah',
#  'Renly Baratheon',
#  'Yoren',
#  'Kevan Lannister',
#  'Rakharo',
#  'Ilyn Payne',
#  'Barristan Selmy',
#  'Rast',
#  'Maester Aemon',
#  'Pypar',
#  'Alliser Thorne',
#  'Othell Yarwyck',
#  'Robin Arryn',
#  'Benjen Stark',
#  'Lysa Arryn',
#  'Septa Mordane',
#  'Qotho',
#  'Jory Cassel',
#  'Marillion',
#  'Greatjon Umber',
#  'Mirri Maz Duur',
#  'Syrio Forel',
#  'Loras Tyrell',
#  'Hot Pie',
#  'Biter',
#  'Rorge',
#  'Lommy Greenhands',
#  'Rickard Karstark',
#  'Beric Dondarrion',
#  'Podrick Payne',
#  'Eddison Tollett',
#  'Yara Greyjoy',
#  'Craster',
#  'Dontos Hollard',
#  'Kovarro',
#  'Dagmer',
#  'Xaro Xhoan Daxos',
#  'Pyat Pree',
#  'Amory Lorch',
#  'Black Lorren',
#  'Qhorin Halfhand',
#  'Spice King',
#  'Silk King',
#  'Alton Lannister',
#  'Selyse Florent',
#  'Little Sam',
#  'Qyburn',
#  'Olenna Tyrell',
#  'Shireen Baratheon',
#  'Meera Reed',
#  'Jojen Reed',
#  'Locke',
#  'Mance Rayder',
#  'Edmure Tully',
#  'Thoros of Myr',
#  'Brynden Tully',
#  'Orell',
#  'Anguy',
#  'Kraznys mo Nakloz',
#  'High Septon',
#  'Myranda',
#  'Olyvar',
#  'Lothar Frey',
#  'Black Walder Rivers',
#  'Olly',
#  'Mace Tyrell',
#  'Oberyn Martell',
#  'Styr',
#  'Thenn warg',
#  'Walda Bolton',
#  'Hizdahr zo Loraq',
#  'Yohn Royce',
#  'Three-Eyed Raven',
#  'Leaf',
#  'Night King',
#  'The Waif',
#  'Bowen Marsh',
#  'Septa Unella',
#  'Tyene Sand',
#  'Nymeria Sand',
#  'Obara Sand',
#  'Areo Hotah',
#  'Doran Martell',
#  'Trystane Martell',
#  'Wun Weg Wun Dar Wun',
#  'Maester Wolkan',
#  'Qhono',
#  'Lyanna Mormont',
#  'Harald Karstark',
#  'Izembaro',
#  'Khal Moro',
#  'Lady Crane',
#  'Bobono',
#  'Clarenzo',
#  'Euron Greyjoy',
#  'Robett Glover',
#  'Randyll Tarly',
#  'Dickon Tarly',
#  'Archmaester Ebrose',
#  'Harrag',
#  'Alys Karstark']

# %% [markdown]
# **We will use web scraping to extract data**

# %%
def getText():
    
    pages_dic={}
    
    for character in list_full:
    
        # parse url character name
        if " " in character:
            character = re.sub(r" ", "_", character)

        url="https://gameofthrones.fandom.com/wiki/" + character # get base url

        response = requests.get(url) # request a server response

        # not found
        if response.status_code == 404:
            print("{} wiki is not found.".format(character))
            continue

        soup = BeautifulSoup(response.text, "html.parser") # parse text from html

        para=soup.findAll('p') # find all paragraphs

        # clean the raw text
        res=[]
        for p in para:
            p = re.sub(r"<.+?>", "", str(p)) # remove all other tags e.g. <a href>
            p = re.sub(r"\[\d+?\]", " ", p)  # remove footnote label e.g. [1], [2]
            p = re.sub(r"\n", "", p)         # remove the nextline character
            p = re.sub(r"\xa0", u" ", p)     # remove empty space due to encoding

            if len(p) != 0 and p[-1] == " ": # remove empty space at the end, if present
                p = p[:-1]
            res.append(p)

        page="".join(res)
        
        pages_dic[character] = page
    
    # save the file
    pickle.dump(pages_dic, open('pages.p', 'wb'))
    return None

# %%
# only run once
# getText()
# Out:
# The_High_Sparrow wiki is not found.
# Grand_Maester_Pycelle wiki is not found.
# Maester_Wolkan wiki is not found.
# Khal_Moro wiki is not found.
# Archmaester_Ebrose wiki is not found.

# %%
infile = open("pages.p",'rb')
pages = pickle.load(infile)
infile.close()

# %%
"The_Waif" in list(pages.keys())
# Out:
# True

# %%
len(pages)
# Out:
# 154

# %% [markdown]
# > Build a network of main charactors.

# %% [markdown]
# * Node is charactor name
# * Edge is their connection identified in wiki page

# %% [markdown]
# However, each character may have many nicknames/alias. In order to achieve higher accuracy, we find out all possible nicknames/alias (tried my best and it is tedious). We build a dictionary with key = Full Name and value = list of nicknames. We only consider nicknames for characters who are featured in https://gameofthrones.fandom.com/wiki/Game_of_Thrones_Wiki.

# %%
def characterDic():
    nicknames={}
    
    for name in pages.keys():
        parsed_name = name.replace("_", " ")
        

        
        
#         if parsed_name == "Margaery Tyrell":
#             print("{} is my FAVORITE female charactor!".format(parsed_name))
        
        # a special case of The, since The Waif is not important, we omit        
        if parsed_name == "The Waif":
            print(parsed_name)
            continue  
        nicknames[parsed_name] = [parsed_name,]
        
        # general case
        if " " in parsed_name: # both first name and last name are present
            firstname = parsed_name.split(" ")[0]
            nicknames[parsed_name] += [firstname,]
#         else: # only first name is present
#             nicknames[parsed_name] = [parsed_name,]
    
    # Some manual editing to improve accuracy
    nicknames["Jon Snow"] += ["Aegon", "Lord Snow"]
#     nicknames["Sansa Stark"] = ["Sansa",]
#     nicknames["Arya Stark"] = ["Arya",]
    nicknames["Bran Stark"] += ["Three-Eyed Raven", "Brandon"]
#     nicknames["Edmure Tully"] = ["Edmure", ]
    nicknames["Davos Seaworth"] += ["Onion Knight", "Davos"]
#     nicknames["Tormund"] = ["Tormund", "Tormund Giantsbane",]
#     nicknames["Meera Reed"] = ["Meera", ]
#     nicknames["Lyanna Mormont"] = ["Lyanna", ]
#     nicknames["Benjen Stark"] = ["Benjen",]
#     nicknames["Cersei Lannister"] = ["Cersei", ]
    nicknames["Jaime Lannister"] += ["Kingslayer"]
    nicknames["Tyrion Lannister"] += ["Imp", "Halfman", "Little Lion"]
#     nicknames["Qyburn"] += ["Qyburn",]
    nicknames["Gregor Clegane"] += ["The Mountain",]
#     nicknames["Bronn"] += ["Bronn",]
#     nicknames["Tywin Lannister"] += ["Tywin",]
    nicknames["Joffrey Baratheon"] += ["Joff"]
#     nicknames["Myrcella Baratheon"] += ["Myrcella",]
#     nicknames["Tommen Baratheon"] += ["Tommen",]
    nicknames["Daenerys Targaryen"] += ["Daenerys Stormborn", "Stormborn", "Dany", 
                                       "Mhysa", "Dragon Queen", "Khaleesi"]
#     nicknames["Rhaegar Targaryen"] = ["Rhaegar"]
    nicknames["Varys"] += ["Spider", "Eunuch"]
#     nicknames["Yara Greyjoy"] += ["Yara",]
    nicknames["Theon Greyjoy"] += ["Reek",]
#     nicknames["Missandei"] += ["Missandei",]
    nicknames["Grey Worm"] += ["Torgo Nudho",]
    nicknames["Olenna Tyrell"] += ["Redwyne",]
#     nicknames["Ellaria Sand"] += ["Ellaria",]
    nicknames["Brienne of Tarth"] += ["Brienne", "Maid of Tarth"]
#     nicknames["Podrick Payne"] += ["Podrick",]
    nicknames["Samwell Tarly"] += ["Sam", "Piggy"]
#     nicknames["Gilly"] += ["Gilly",]
    nicknames["Gendry Baratheon"] = ["Gendry", "Clovis"]
    nicknames["Petyr Baelish"] += ["Littlefinger", "Baelish"]
    print("Yeah, my FAVORITE male character Sandor Clegane!")
    nicknames["Sandor Clegane"] += ["Hound"]
    nicknames["Melisandre"] += ["Red Woman", "Red Witch"]
#     nicknames["Euron Greyjoy"] += ["Euron", ]
#     nicknames["Night King"] += ["Night King",]
    
    return nicknames

# %%
characters=characterDic()
# Out:
# The Waif
# Yeah, my FAVORITE male character Sandor Clegane!

# %%
def edgeWeight():
    # key = (A,B), value = N
    # In wiki page of A, B is mentioned N times
    res_dic={}
    
    # loop through each character
    for ch in characters:
        
        # obtain all his names/alias
        alias=characters[ch]
        
        # loop through every wikipages
        for name in pages:
            if name == "The_Waif":
                continue
                
            parsed_name = name.replace("_", " ")
            
            # obtain the text
            text=pages[name] 
            
            # prevent self loop --> Jon Snow page mentions Jon Snow himself N times
            if parsed_name != ch:
                for al in alias:
                    text=text.replace(al, ch)
                
                count=text.count(ch)
                    
                # update result dictionary
                if count != 0:
                    res_dic[(parsed_name, ch)]=count

    return res_dic

# %%
edgeWightDic=edgeWeight()

# %%
G=nx.DiGraph()
G.add_nodes_from(characters.keys())
G.add_edges_from([(k[0],k[1],{"weight" : v}) for (k,v) in edgeWightDic.items()])

# %%
G.nodes
# Out:
# NodeView(('Eddard Stark', 'Robert Baratheon', 'Jaime Lannister', 'Catelyn Stark', 'Cersei Lannister', 'Daenerys Targaryen', 'Jorah Mormont', 'Viserys Targaryen', 'Jon Snow', 'Sansa Stark', 'Arya Stark', 'Robb Stark', 'Theon Greyjoy', 'Bran Stark', 'Joffrey Baratheon', 'Sandor Clegane', 'Tyrion Lannister', 'Khal Drogo', 'Petyr Baelish', 'Davos Seaworth', 'Samwell Tarly', 'Stannis Baratheon', 'Melisandre', 'Jeor Mormont', 'Bronn', 'Varys', 'Shae', 'Margaery Tyrell', 'Tywin Lannister', 'Talisa Maegyr', 'Ygritte', 'Gendry', 'Tormund Giantsbane', 'Brienne of Tarth', 'Ramsay Bolton', 'Gilly', 'Daario Naharis', 'Missandei', 'Ellaria Sand', 'Tommen Baratheon', "Jaqen H'ghar", 'Roose Bolton', 'Grey Worm', 'Meryn Trant', 'Hodor', 'Grenn', 'Osha', 'Rickon Stark', 'Ros', 'Gregor Clegane', 'Janos Slynt', 'Lancel Lannister', 'Myrcella Baratheon', 'Rodrik Cassel', 'Maester Luwin', 'Irri', 'Doreah', 'Renly Baratheon', 'Yoren', 'Kevan Lannister', 'Rakharo', 'Ilyn Payne', 'Barristan Selmy', 'Rast', 'Maester Aemon', 'Pypar', 'Alliser Thorne', 'Othell Yarwyck', 'Robin Arryn', 'Benjen Stark', 'Lysa Arryn', 'Septa Mordane', 'Qotho', 'Jory Cassel', 'Marillion', 'Greatjon Umber', 'Mirri Maz Duur', 'Syrio Forel', 'Loras Tyrell', 'Hot Pie', 'Biter', 'Rorge', 'Lommy Greenhands', 'Rickard Karstark', 'Beric Dondarrion', 'Podrick Payne', 'Eddison Tollett', 'Yara Greyjoy', 'Craster', 'Dontos Hollard', 'Kovarro', 'Dagmer', 'Xaro Xhoan Daxos', 'Pyat Pree', 'Amory Lorch', 'Black Lorren', 'Qhorin Halfhand', 'Spice King', 'Silk King', 'Alton Lannister', 'Selyse Florent', 'Little Sam', 'Qyburn', 'Olenna Tyrell', 'Shireen Baratheon', 'Meera Reed', 'Jojen Reed', 'Locke', 'Mance Rayder', 'Edmure Tully', 'Thoros of Myr', 'Brynden Tully', 'Orell', 'Anguy', 'Kraznys mo Nakloz', 'High Septon', 'Myranda', 'Olyvar', 'Lothar Frey', 'Black Walder Rivers', 'Olly', 'Mace Tyrell', 'Oberyn Martell', 'Styr', 'Thenn warg', 'Walda Bolton', 'Hizdahr zo Loraq', 'Yohn Royce', 'Three-Eyed Raven', 'Leaf', 'Night King', 'Bowen Marsh', 'Septa Unella', 'Tyene Sand', 'Nymeria Sand', 'Obara Sand', 'Areo Hotah', 'Doran Martell', 'Trystane Martell', 'Wun Weg Wun Dar Wun', 'Qhono', 'Lyanna Mormont', 'Harald Karstark', 'Izembaro', 'Lady Crane', 'Bobono', 'Clarenzo', 'Euron Greyjoy', 'Robett Glover', 'Randyll Tarly', 'Dickon Tarly', 'Harrag', 'Alys Karstark', 'Gendry Baratheon'))

# %%
forceatlas2 = ForceAtlas2(
                        # Behavior alternatives
                        outboundAttractionDistribution=True,  # Dissuade hubs
                        linLogMode=False,  # NOT IMPLEMENTED
                        adjustSizes=False,  # Prevent overlap (NOT IMPLEMENTED)
                        edgeWeightInfluence=0,

                        # Performance
                        jitterTolerance=0.0001,  # Tolerance
                        barnesHutOptimize=True,
                        barnesHutTheta=0.08,
                        multiThreaded=False,  # NOT IMPLEMENTED

                        # Tuning
                        scalingRatio=0.001,
                        strongGravityMode=False,
                        gravity=0,

                        # Log
                        verbose=False)
positions = forceatlas2.forceatlas2_networkx_layout(G.to_undirected(), 
                                                    pos=None,iterations=1000)

# %%
G.degree(weight="weight")
# Out:
# DiDegreeView({'Eddard Stark': 1220, 'Robert Baratheon': 1175, 'Jaime Lannister': 2620, 'Catelyn Stark': 1130, 'Cersei Lannister': 2868, 'Daenerys Targaryen': 2925, 'Jorah Mormont': 920, 'Viserys Targaryen': 281, 'Jon Snow': 4285, 'Sansa Stark': 2841, 'Arya Stark': 1948, 'Robb Stark': 1518, 'Theon Greyjoy': 1527, 'Bran Stark': 1561, 'Joffrey Baratheon': 1513, 'Sandor Clegane': 864, 'Tyrion Lannister': 3309, 'Khal Drogo': 181, 'Petyr Baelish': 1564, 'Davos Seaworth': 1106, 'Samwell Tarly': 1359, 'Stannis Baratheon': 1603, 'Melisandre': 881, 'Jeor Mormont': 312, 'Bronn': 820, 'Varys': 977, 'Shae': 453, 'Margaery Tyrell': 831, 'Tywin Lannister': 1315, 'Talisa Maegyr': 209, 'Ygritte': 331, 'Gendry': 855, 'Tormund Giantsbane': 713, 'Brienne of Tarth': 1314, 'Ramsay Bolton': 1223, 'Gilly': 592, 'Daario Naharis': 381, 'Missandei': 555, 'Ellaria Sand': 640, 'Tommen Baratheon': 602, "Jaqen H'ghar": 260, 'Roose Bolton': 593, 'Grey Worm': 788, 'Meryn Trant': 260, 'Hodor': 294, 'Grenn': 317, 'Osha': 309, 'Rickon Stark': 446, 'Ros': 249, 'Gregor Clegane': 665, 'Janos Slynt': 382, 'Lancel Lannister': 364, 'Myrcella Baratheon': 665, 'Rodrik Cassel': 249, 'Maester Luwin': 335, 'Irri': 156, 'Doreah': 129, 'Renly Baratheon': 851, 'Yoren': 227, 'Kevan Lannister': 403, 'Rakharo': 108, 'Ilyn Payne': 140, 'Barristan Selmy': 462, 'Rast': 197, 'Maester Aemon': 421, 'Pypar': 168, 'Alliser Thorne': 451, 'Othell Yarwyck': 144, 'Robin Arryn': 245, 'Benjen Stark': 235, 'Lysa Arryn': 360, 'Septa Mordane': 117, 'Qotho': 49, 'Jory Cassel': 80, 'Marillion': 76, 'Greatjon Umber': 83, 'Mirri Maz Duur': 44, 'Syrio Forel': 98, 'Loras Tyrell': 791, 'Hot Pie': 273, 'Biter': 115, 'Rorge': 155, 'Lommy Greenhands': 93, 'Rickard Karstark': 214, 'Beric Dondarrion': 339, 'Podrick Payne': 608, 'Eddison Tollett': 434, 'Yara Greyjoy': 522, 'Craster': 316, 'Dontos Hollard': 120, 'Kovarro': 68, 'Dagmer': 103, 'Xaro Xhoan Daxos': 158, 'Pyat Pree': 66, 'Amory Lorch': 89, 'Black Lorren': 882, 'Qhorin Halfhand': 146, 'Spice King': 49, 'Silk King': 13, 'Alton Lannister': 100, 'Selyse Florent': 174, 'Little Sam': 717, 'Qyburn': 486, 'Olenna Tyrell': 648, 'Shireen Baratheon': 323, 'Meera Reed': 265, 'Jojen Reed': 257, 'Locke': 351, 'Mance Rayder': 451, 'Edmure Tully': 320, 'Thoros of Myr': 230, 'Brynden Tully': 283, 'Orell': 82, 'Anguy': 38, 'Kraznys mo Nakloz': 56, 'High Septon': 360, 'Myranda': 177, 'Olyvar': 129, 'Lothar Frey': 101, 'Black Walder Rivers': 902, 'Olly': 165, 'Mace Tyrell': 295, 'Oberyn Martell': 471, 'Styr': 103, 'Thenn warg': 48, 'Walda Bolton': 98, 'Hizdahr zo Loraq': 165, 'Yohn Royce': 217, 'Three-Eyed Raven': 214, 'Leaf': 58, 'Night King': 905, 'Bowen Marsh': 125, 'Septa Unella': 101, 'Tyene Sand': 315, 'Nymeria Sand': 251, 'Obara Sand': 239, 'Areo Hotah': 162, 'Doran Martell': 420, 'Trystane Martell': 205, 'Wun Weg Wun Dar Wun': 104, 'Qhono': 45, 'Lyanna Mormont': 260, 'Harald Karstark': 119, 'Izembaro': 15, 'Lady Crane': 270, 'Bobono': 18, 'Clarenzo': 3, 'Euron Greyjoy': 402, 'Robett Glover': 90, 'Randyll Tarly': 326, 'Dickon Tarly': 162, 'Harrag': 38, 'Alys Karstark': 134, 'Gendry Baratheon': 445})

# %%
labeling={}
for node in G.nodes:
    if G.degree(weight="weight")[node] > 1500:
        labeling[node] = node
nodeSize=[G.degree(weight="weight")[character] for character in G.nodes]      

plt.figure(figsize=(15,10))
plt.axis("off")
nx.draw_networkx_edges(G, positions, width = 0.1, alpha = 0.3, arrows=False)
nx.draw_networkx_nodes(G, positions,alpha= 0.7, 
                       node_size=[size/sum(nodeSize) * 100000/3 for size in nodeSize])
nx.draw_networkx_labels(G, positions, labels=labeling, font_size=15)
plt.show()

# %% [markdown]
# Some helper function before giving our awards.

# %%
def getColorList(champion, first_runner_up, second_runner_up):
    colorList=[]
    for node in G.nodes:
        if node == champion:
            colorList.append("#ffd700") # gold
        elif node == first_runner_up:
            colorList.append("#aaa9ad") # silver
        elif node == second_runner_up:
            colorList.append("#cd7f32") # bronze
        else:
            colorList.append("#0000ff")
    return colorList

# %%
def getLabeling(sortedList, topN):
    labeling={}
    for node in G.nodes:
        if node in list(map(lambda x : x[0], sortedList[:topN])):
            labeling[node] = node
    return labeling

# %%
def plot(sizes,colors,labeling, adjustFactor):
    plt.figure(figsize=(15,10))
    plt.axis("off")
    nx.draw_networkx_edges(G, positions, width = 0.1, alpha = 0.3, arrows=False)
    nx.draw_networkx_nodes(G, positions,alpha= 0.7, node_color=colors,
                           node_size=[size * adjustFactor for size in sizes])
    nx.draw_networkx_labels(G, positions, labels=labeling, font_size=12)
    plt.show()
    return

# %% [markdown]
# ## Most Mentioned Award

# %% [markdown]
# Who is mentioned the most number of times in others' wiki page?

# %%
sorting=sorted(list(G.in_degree(weight="weight")), key=lambda x : x[1], reverse=True)
top3=sorting[:3]
top3
# Out:
# [('Jon Snow', 2881), ('Daenerys Targaryen', 2030), ('Tyrion Lannister', 1990)]

# %%
plot([G.in_degree(weight="weight")[character] for character in G.nodes],
     getColorList('Jon Snow','Daenerys Targaryen','Tyrion Lannister'),
     getLabeling(sorting, 10),1)

# %% [markdown]
# ## The most mentioned award goes to........The Waif!

# %% [markdown]
# ## Most Social Award

# %% [markdown]
# Whose page mentioned the most number of other characters?

# %%
sorting=sorted(list(G.out_degree(weight="weight")), key=lambda x : x[1], reverse=True)
top3=sorting[:3]
top3
# Out:
# [('Sansa Stark', 1406), ('Jon Snow', 1404), ('Tyrion Lannister', 1319)]

# %%
plot([G.out_degree(weight="weight")[character] for character in G.nodes],
     getColorList('Sansa Stark','Jon Snow','Tyrion Lannister'),
     getLabeling(sorting, 10),1)

# %% [markdown]
# ## The most social award goes to........Jon Snow!

# %% [markdown]
# ## Most "Closeness" Award

# %% [markdown]
# Who is on average closest other characters?

# %%
sorting=sorted(list(nx.closeness_centrality(G).items()), key=lambda x : x[1], reverse=True)
top3=sorting[:3]
top3
# Out:
# [('Jon Snow', 0.7704415099373082),
#  ('Black Lorren', 0.7259929612870789),
#  ('Black Walder Rivers', 0.7259929612870789)]

# %%
plot(list(nx.closeness_centrality(G).values()),
     getColorList('Jon Snow','Black Lorren','Black Walder Rivers'),
     getLabeling(sorting, 10), 300)

# %% [markdown]
# ## The most social award goes to........Jon Snow!

# %%
sorting=sorted(list(nx.closeness_centrality(G)), key=lambda x : x[1], reverse=True)
sorting
# Out:
# ['Izembaro',
#  'Tyrion Lannister',
#  'Tywin Lannister',
#  'Myrcella Baratheon',
#  'Pypar',
#  'Lysa Arryn',
#  'Syrio Forel',
#  'Pyat Pree',
#  'Qyburn',
#  'Myranda',
#  'Tyene Sand',
#  'Nymeria Sand',
#  'Lyanna Mormont',
#  'Wun Weg Wun Dar Wun',
#  'Euron Greyjoy',
#  'Stannis Baratheon',
#  'Othell Yarwyck',
#  'Styr',
#  'Osha',
#  'Arya Stark',
#  'Bran Stark',
#  'Bronn',
#  'Brienne of Tarth',
#  'Grey Worm',
#  'Grenn',
#  'Gregor Clegane',
#  'Irri',
#  'Greatjon Umber',
#  'Craster',
#  'Brynden Tully',
#  'Orell',
#  'Kraznys mo Nakloz',
#  'Areo Hotah',
#  'Trystane Martell',
#  'Spice King',
#  'Robert Baratheon',
#  'Jorah Mormont',
#  'Jon Snow',
#  'Robb Stark',
#  'Joffrey Baratheon',
#  'Tormund Giantsbane',
#  'Tommen Baratheon',
#  'Roose Bolton',
#  'Hodor',
#  'Ros',
#  'Rodrik Cassel',
#  'Doreah',
#  'Yoren',
#  'Robin Arryn',
#  'Qotho',
#  'Jory Cassel',
#  'Loras Tyrell',
#  'Hot Pie',
#  'Rorge',
#  'Lommy Greenhands',
#  'Podrick Payne',
#  'Dontos Hollard',
#  'Kovarro',
#  'Jojen Reed',
#  'Locke',
#  'Lothar Frey',
#  'Yohn Royce',
#  'Bowen Marsh',
#  'Doran Martell',
#  'Bobono',
#  'Robett Glover',
#  'Tormund',
#  'Anguy',
#  'Amory Lorch',
#  'Ellaria Sand',
#  'Ilyn Payne',
#  'Alliser Thorne',
#  'Black Lorren',
#  'Alton Lannister',
#  'Olenna Tyrell',
#  'Olyvar',
#  'Black Walder Rivers',
#  'Olly',
#  'Clarenzo',
#  'Alys Karstark',
#  'Viserys Targaryen',
#  'Gilly',
#  'Missandei',
#  'Rickon Stark',
#  'Mirri Maz Duur',
#  'Biter',
#  'Rickard Karstark',
#  'Silk King',
#  'Little Sam',
#  'High Septon',
#  'Hizdahr zo Loraq',
#  'Night King',
#  'Dickon Tarly',
#  'Theon Greyjoy',
#  'Khal Drogo',
#  'Shae',
#  'Qhorin Halfhand',
#  'Shireen Baratheon',
#  'Thoros of Myr',
#  'Thenn warg',
#  'Three-Eyed Raven',
#  'The Waif',
#  'Qhono',
#  'Rhaegar Targaryen',
#  'Ygritte',
#  'Cersei Lannister',
#  'Petyr Baelish',
#  'Melisandre',
#  'Jeor Mormont',
#  'Gendry',
#  'Meryn Trant',
#  'Renly Baratheon',
#  'Kevan Lannister',
#  'Benjen Stark',
#  'Septa Mordane',
#  'Beric Dondarrion',
#  'Selyse Florent',
#  'Meera Reed',
#  'Leaf',
#  'Septa Unella',
#  'Gendry Baratheon',
#  'Eddard Stark',
#  'Eddison Tollett',
#  'Edmure Tully',
#  'Oberyn Martell',
#  'Obara Sand',
#  'Jaime Lannister',
#  'Catelyn Stark',
#  'Daenerys Targaryen',
#  'Sansa Stark',
#  'Sandor Clegane',
#  'Davos Seaworth',
#  'Samwell Tarly',
#  'Varys',
#  'Margaery Tyrell',
#  'Talisa Maegyr',
#  'Ramsay Bolton',
#  'Daario Naharis',
#  "Jaqen H'ghar",
#  'Janos Slynt',
#  'Lancel Lannister',
#  'Maester Luwin',
#  'Rakharo',
#  'Barristan Selmy',
#  'Rast',
#  'Maester Aemon',
#  'Marillion',
#  'Yara Greyjoy',
#  'Dagmer',
#  'Xaro Xhoan Daxos',
#  'Mance Rayder',
#  'Mace Tyrell',
#  'Walda Bolton',
#  'Harald Karstark',
#  'Lady Crane',
#  'Randyll Tarly',
#  'Harrag']
